# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %%
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
sns.set_style('darkgrid')
plt.figure(figsize = (10,6))
sns.heatmap(df.isnull(),cmap ='magma')
# Out:
# <AxesSubplot:>

# %%
df.fillna(df['total_bedrooms'].mean(),inplace =True)

# %%
df.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
corr = df.corr()

# %%
corr
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069260 -0.066658           -0.318998     0.927253
# population           0.099773 -0.108785           -0.296244     0.857126
# households           0.055310 -0.071035           -0.302916     0.918484
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.069260    0.099773    0.055310      -0.015176
# latitude                 -0.066658   -0.108785   -0.071035      -0.079809
# ...

# %%
df.describe(exclude ='object')
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20640.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        419.266592   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
plt.figure(figsize = (10,6))
sns.histplot(data = df, x = df['housing_median_age'], hue = 'ocean_proximity',multiple = 'stack',palette ='mako')
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data = df, x = df['median_income'], hue = 'ocean_proximity',multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data = df, x = df['median_house_value'], hue = 'ocean_proximity',multiple = 'stack',palette = 'bright')
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))
sns.histplot(data = df, x = df['population'], hue = 'ocean_proximity',multiple = 'stack')
# Out:
# <AxesSubplot:xlabel='population', ylabel='Count'>

# %%
plt.figure(figsize = (10,6))

sns.scatterplot(data = df,x ='longitude',y ='latitude',hue ='ocean_proximity', palette = 'dark' )
# Out:
# <AxesSubplot:xlabel='longitude', ylabel='latitude'>

# %%
inputs = df.iloc[:,0:8]
targets =df['median_house_value']

# %%
inputs
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income
# ...

# %%
targets
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs,targets, test_size=0.33, random_state=42)

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
s1 = svr.score(X_train, y_train)
s2 = svr.score(X_test, y_test)

# %%
# model performa horriblly
print("R² of Support Vector Regressor on training set: {:.3f}".format(s1))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s2))
# Out:
# R² of Support Vector Regressor on training set: -0.055
# R² of Support Vector Regressor on test set: -0.058

# %%
Y_train = y_train.values.reshape(-1,1)
Y_test = y_test.values.reshape(-1,1)

# %%
#lets do feature scaling 
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)
y_train_scaled = scaler.fit_transform(Y_train)
y_test_scaled = scaler.fit_transform(Y_test)

# %%
svr1 = SVR()
svr1.fit(X_train_scaled,y_train_scaled)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# SVR()

# %%
s3 = svr1.score(X_train_scaled, y_train_scaled)
s4 = svr1.score(X_test_scaled, y_test_scaled)

# %%
# underfiiting problem performance is good on training and  bad on test data
print("R² of Support Vector Regressor on training set: {:.3f}".format(s3))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s4))
# Out:
# R² of Support Vector Regressor on training set: 0.738
# R² of Support Vector Regressor on test set: 0.316

# %%
svr2 = SVR(C=2.0)
svr2.fit(X_train_scaled, y_train_scaled)
s5 = svr2.score(X_train_scaled, y_train_scaled)
s6 = svr2.score(X_test_scaled, y_test_scaled)
print("R² of Support Vector Regressor on training set: {:.3f}".format(s5))
print("R² of Support Vector Regressor on test set: {:.3f}".format(s6))
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# R² of Support Vector Regressor on training set: 0.745
# R² of Support Vector Regressor on test set: 0.213
