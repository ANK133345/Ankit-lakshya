# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\excel\100-days-of-machine-learning-main\day25-normalization\wine_data.csv')

# %%
df.columns = ['Class','Alcohol','Malic acid','Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid', 'phenolsProanthocyanins','Color intensity','Hue','OD280/OD315 of diluted wines','Proline']

# %%
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    13.20        1.78  2.14               11.2        100
# 1        1    13.16        2.36  2.67               18.6        101
# 2        1    14.37        1.95  2.50               16.8        113
# 3        1    13.24        2.59  2.87               21.0        118
# 4        1    14.20        1.76  2.45               15.2        112
# ..     ...      ...         ...   ...                ...        ...
# 172      3    13.71        5.65  2.45               20.5         95
# 173      3    13.40        3.91  2.48               23.0        102
# 174      3    13.27        4.28  2.26               20.0        120
# 175      3    13.17        2.59  2.37               20.0        120
# 176      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid  phenolsProanthocyanins  \
# 0             2.65        2.76          0.26                    1.28
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Class                         177 non-null    int64
#  1   Alcohol                       177 non-null    float64
#  2   Malic acid                    177 non-null    float64
#  3   Ash                           177 non-null    float64
#  4   Alcalinity of ash             177 non-null    float64
#  5   Magnesium                     177 non-null    int64
#  6   Total phenols                 177 non-null    float64
#  7   Flavanoids                    177 non-null    float64
#  8   Nonflavanoid                  177 non-null    float64
#  9   phenolsProanthocyanins        177 non-null    float64
#  10  Color intensity               177 non-null    float64
#  11  Hue                           177 non-null    float64
# ...

# %%
df.iloc[:,1:].describe()
# Out:
#           Alcohol  Malic acid         Ash  Alcalinity of ash   Magnesium  \
# count  177.000000  177.000000  177.000000         177.000000  177.000000
# mean    12.993672    2.339887    2.366158          19.516949   99.587571
# std      0.808808    1.119314    0.275080           3.336071   14.174018
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.360000    1.600000    2.210000          17.200000   88.000000
# 50%     13.050000    1.870000    2.360000          19.500000   98.000000
# 75%     13.670000    3.100000    2.560000          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        Total phenols  Flavanoids  Nonflavanoid  phenolsProanthocyanins  \
# count     177.000000  177.000000    177.000000              177.000000
# mean        2.292260    2.023446      0.362316                1.586949
# std         0.626465    0.998658      0.124653                0.571545
# ...

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
# %matplotlib inline
for c in df.columns[1:]:
    df.boxplot(c,by = 'Class',figsize = (7,4),fontsize=10)
plt.xlabel('WineClass')
plt.title("{}\n".format(c),fontsize=13)
# Out:
# Text(0.5, 1.0, 'Proline\n')

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
X = scaler.fit_transform(X)

# %%
dfx = pd.DataFrame(data=X,columns=df.columns[1:])

# %%
dfx.head(10)
# Out:
#     Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0  0.255824   -0.501624 -0.824485          -2.500110   0.029180
# 1  0.206229    0.018020  1.107690          -0.275639   0.099932
# 2  1.706501   -0.349315  0.487935          -0.816726   0.948953
# 3  0.305420    0.224086  1.836812           0.445811   1.302712
# 4  1.495719   -0.519543  0.305655          -1.297693   0.878201
# 5  1.731299   -0.420990  0.305655          -1.478055  -0.253827
# 6  1.322133   -0.170127  0.888953          -0.576243   1.514967
# 7  2.276852   -0.627056 -0.715117          -1.658418  -0.183075
# 8  1.074155   -0.886878 -0.350556          -1.057210  -0.112323
# 9  1.371729   -0.161168 -0.241187          -0.456001   0.382939
#
#    Total phenols  Flavanoids  Nonflavanoid  phenolsProanthocyanins  \
# 0       0.572666    0.739636     -0.823139               -0.538575
# 1       0.812784    1.221645     -0.501337                2.145975
# ...

# %%
dfx.describe()
# Out:
#             Alcohol    Malic acid           Ash  Alcalinity of ash  \
# count  1.770000e+02  1.770000e+02  1.770000e+02       1.770000e+02
# mean  -2.609338e-16  4.252719e-16 -4.378168e-16      -6.410440e-16
# std    1.002837e+00  1.002837e+00  1.002837e+00       1.002837e+00
# min   -2.434746e+00 -1.433400e+00 -3.668064e+00      -2.680472e+00
# 25%   -7.856866e-01 -6.628933e-01 -5.692924e-01      -6.964846e-01
# 50%    6.984037e-02 -4.209899e-01 -2.245039e-02      -5.094986e-03
# 75%    8.385748e-01  6.810145e-01  7.066723e-01       5.961134e-01
# max    2.276852e+00  3.100048e+00  3.149233e+00       3.151249e+00
#
#           Magnesium  Total phenols    Flavanoids  Nonflavanoid  \
# count  1.770000e+02   1.770000e+02  1.770000e+02  1.770000e+02
# mean  -1.028681e-16  -1.279579e-16  1.505387e-16 -5.595022e-16
# std    1.002837e+00   1.002837e+00  1.002837e+00  1.002837e+00
# min   -2.093373e+00  -2.100648e+00 -1.690491e+00 -1.868993e+00
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components = 2)
pca.fit(dfx)
x_pca = pca.transform(dfx)
x_pca.shape
# Out:
# (177, 2)

# %%
dfx_trans = pd.DataFrame(data= x_pca)
dfx_trans.head(10)
# Out:
#           0         1
# 0  2.230243  0.302313
# 1  2.531922 -1.062257
# 2  3.754677 -2.805309
# 3  1.020131 -0.888380
# 4  3.049199 -2.170007
# 5  2.458228 -1.207065
# 6  2.061605 -1.640485
# 7  2.518445 -0.960837
# 8  2.767971 -0.824521
# 9  3.489161 -1.355190

# %%
plt.figure(figsize =(8, 6))
sns.scatterplot(dfx_trans[0],dfx_trans[1],c = df['Class'],cmap ='cividis')
plt.title("Class separation using first two principal components\n",fontsize=20)
plt.xlabel("Principal component-1",fontsize=15)
plt.ylabel("Principal component-2",fontsize=15)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
